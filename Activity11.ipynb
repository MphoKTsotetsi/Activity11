# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
sample_data = pd.read_csv("tips.csv")
sample_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
sample_data ["Net bill"] = sample_data["total_bill"] - sample data["tips"]
# Out:
#   File "<ipython-input-9-67e15b5206f7>", line 1
#     sample_data ["Net bill"] = sample_data["total_bill"] - sample data["tips"]
#                                                                      ^
# SyntaxError: invalid syntax

# %%
sample_data["Net_bill"] = sample_data["total_bill"] - sample_data["tip"]
sample_data
# Out:
#      total_bill   tip     sex smoker   day    time  size  Net_bill
# 0         16.99  1.01  Female     No   Sun  Dinner     2     15.98
# 1         10.34  1.66    Male     No   Sun  Dinner     3      8.68
# 2         21.01  3.50    Male     No   Sun  Dinner     3     17.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2     20.37
# 4         24.59  3.61  Female     No   Sun  Dinner     4     20.98
# 5         25.29  4.71    Male     No   Sun  Dinner     4     20.58
# 6          8.77  2.00    Male     No   Sun  Dinner     2      6.77
# 7         26.88  3.12    Male     No   Sun  Dinner     4     23.76
# 8         15.04  1.96    Male     No   Sun  Dinner     2     13.08
# 9         14.78  3.23    Male     No   Sun  Dinner     2     11.55
# 10        10.27  1.71    Male     No   Sun  Dinner     2      8.56
# 11        35.26  5.00  Female     No   Sun  Dinner     4     30.26
# 12        15.42  1.57    Male     No   Sun  Dinner     2     13.85
# ...

# %%
#Create a subset based on a condition

# %%
Lunch = sample_data [sample_data.time == 'Lunch']

# %%
Lunch
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 77        27.20  4.00    Male     No  Thur  Lunch     4
# 78        22.76  3.00    Male     No  Thur  Lunch     2
# 79        17.29  2.71    Male     No  Thur  Lunch     2
# 80        19.44  3.00    Male    Yes  Thur  Lunch     2
# 81        16.66  3.40    Male     No  Thur  Lunch     2
# 82        10.07  1.83  Female     No  Thur  Lunch     1
# 83        32.68  5.00    Male    Yes  Thur  Lunch     2
# 84        15.98  2.03    Male     No  Thur  Lunch     2
# 85        34.83  5.17  Female     No  Thur  Lunch     4
# 86        13.03  2.00    Male     No  Thur  Lunch     2
# 87        18.28  4.00    Male     No  Thur  Lunch     2
# 88        24.71  5.85    Male     No  Thur  Lunch     2
# 89        21.16  3.00    Male     No  Thur  Lunch     2
# 117       10.65  1.50  Female     No  Thur  Lunch     2
# 118       12.43  1.80  Female     No  Thur  Lunch     2
# 119       24.08  2.92  Female     No  Thur  Lunch     4
# ...

# %%
Dinner = sample_data [sample_data.time == 'Dinner']

# %%
Dinner
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
plt.plot(Lunch.time , Lunch.size)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-6e35d7359d6d> in <module>
#       1
# ----> 2 plt.plot(Lunch.time , Lunch.size)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.plot(sample_data.time,sample_data.size)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-afc1dabfd61f> in <module>
# ----> 1 plt.plot(sample_data.time,sample_data.size)
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(Lunch.size , Lunch.tip)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-751f2140a78b> in <module>
# ----> 1 plt.plot(Lunch.size , Lunch.day)
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.plot(Lunch.size , Lunch.tip)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-e1ecb4b35aec> in <module>
# ----> 1 plt.plot(Lunch.size , Lunch.tip)
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
plt.plot(Lunch.size , Lunch.tip)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e1ecb4b35aec> in <module>
# ----> 1 plt.plot(Lunch.size , Lunch.tip)
#       2 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.plot(Lunch.size, Lunch.tip)
plt.title("Number of people eating lunch/dinner")
plt.xlabel("Lunch")
plt.ylabel("Size of people")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-992b567b50a8> in <module>
# ----> 1 plt.plot(Lunch.size, Lunch.tip)
#       2 plt.title("Number of people eating lunch/dinner")
#       3 plt.xlabel("Lunch")
#       4 plt.ylabel("Size of people")
#       5 plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
plt.plot(sample_data.time, sample_data.tip)
plt.title("Number of people eating lunch/dinner")
plt.xlabel("Lunch")
plt.ylabel("Size of people")
plt.show()

# %%
import numpy

# %%
numpy.corrcoef(sample_data.total_bill, sample_data.tip)[0,1]
# Out:
# 0.6757341092113641

# %%
numpy.corrcoef(sample_data.total_bill, sample_data.size)[0,6]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-4538ae67c594> in <module>
# ----> 1 numpy.corrcoef(sample_data.total_bill, sample_data.size)[0,6]
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    2520         warnings.warn('bias and ddof have no effect and are deprecated',
#    2521                       DeprecationWarning, stacklevel=2)
# -> 2522     c = cov(x, y, rowvar)
#    2523     try:
#    2524         d = diag(c)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2384         if not rowvar and y.shape[0] != 1:
#    2385             y = y.T
# -> 2386         X = np.concatenate((X, y), axis=0)
#    2387
#    2388     if ddof is None:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly
